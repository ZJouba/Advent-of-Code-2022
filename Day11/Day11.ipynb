# %% [markdown]
# <a href="https://colab.research.google.com/github/ZJouba/Advent-of-Code-2022/blob/main/Day11/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import numpy as np

# file = requests.get('https://raw.githubusercontent.com/ZJouba/Advent-of-Code-2022/main/Day10/Day10.txt')
# input = [[a.split(' ')[0], int(a.split(' ')[1]) if len(a.split(' '))>1 else '', 2 if a.split(' ')[0] == 'addx' else 1] for a in list(filter(None, file.text.split('\n')))]

file = '''addx 15
addx -11
addx 6
addx -3
addx 5
addx -1
addx -8
addx 13
addx 4
noop
addx -1
addx 5
addx -1
addx 5
addx -1
addx 5
addx -1
addx 5
addx -1
addx -35
addx 1
addx 24
addx -19
addx 1
addx 16
addx -11
noop
noop
addx 21
addx -15
noop
noop
addx -3
addx 9
addx 1
addx -3
addx 8
addx 1
addx 5
noop
noop
noop
noop
noop
addx -36
noop
addx 1
addx 7
noop
noop
noop
addx 2
addx 6
noop
noop
noop
noop
noop
addx 1
noop
noop
addx 7
addx 1
noop
addx -13
addx 13
addx 7
noop
addx 1
addx -33
noop
noop
noop
addx 2
noop
noop
noop
addx 8
noop
addx -1
addx 2
addx 1
noop
addx 17
addx -9
addx 1
addx 1
addx -3
addx 11
noop
noop
addx 1
noop
addx 1
noop
noop
addx -13
addx -19
addx 1
addx 3
addx 26
addx -30
addx 12
addx -1
addx 3
addx 1
noop
noop
noop
addx -9
addx 18
addx 1
addx 2
noop
noop
addx 9
noop
noop
noop
addx -1
addx 2
addx -37
addx 1
addx 3
noop
addx 15
addx -21
addx 22
addx -6
addx 1
noop
addx 2
addx 1
noop
addx -10
noop
noop
addx 20
addx 1
addx 2
addx 2
addx -6
addx -11
noop
noop
noop'''
input = [[a.split(' ')[0], int(a.split(' ')[1]) if len(a.split(' '))>1 else '', 2 if a.split(' ')[0] == 'addx' else 1] for a in list(filter(None, file.split('\n')))]

for i in range(1, len(input)):
  input[i][2] += input[i-1][2]

print(input)
# Out:
# [['addx', 15, 2], ['addx', -11, 4], ['addx', 6, 6], ['addx', -3, 8], ['addx', 5, 10], ['addx', -1, 12], ['addx', -8, 14], ['addx', 13, 16], ['addx', 4, 18], ['noop', '', 19], ['addx', -1, 21], ['addx', 5, 23], ['addx', -1, 25], ['addx', 5, 27], ['addx', -1, 29], ['addx', 5, 31], ['addx', -1, 33], ['addx', 5, 35], ['addx', -1, 37], ['addx', -35, 39], ['addx', 1, 41], ['addx', 24, 43], ['addx', -19, 45], ['addx', 1, 47], ['addx', 16, 49], ['addx', -11, 51], ['noop', '', 52], ['noop', '', 53], ['addx', 21, 55], ['addx', -15, 57], ['noop', '', 58], ['noop', '', 59], ['addx', -3, 61], ['addx', 9, 63], ['addx', 1, 65], ['addx', -3, 67], ['addx', 8, 69], ['addx', 1, 71], ['addx', 5, 73], ['noop', '', 74], ['noop', '', 75], ['noop', '', 76], ['noop', '', 77], ['noop', '', 78], ['addx', -36, 80], ['noop', '', 81], ['addx', 1, 83], ['addx', 7, 85], ['noop', '', 86], ['noop', '', 87], ['noop', '', 88], ['addx', 2, 90], ['addx', 6, 92], ['noop', '', 93], ['noop', '', 94], ['noop', '', 95], ['noop', '', 96], ['noop', '', 97], ['addx', 1, 99], ['noop', '', 100], ['noop', '', 101], ['addx', 7, 103], ['addx', 1, 105], ['noop', '', 106], ['addx', -13, 108], ['addx', 13, 110], ['addx', 7, 112], ['noop', '', 113], ['addx', 1, 115], ['addx', -33, 117], ['noop', '', 118], ['noop', '', 119], ['noop', '', 120], ['addx', 2, 122], ['noop', '', 123], ['noop', '', 124], ['noop', '', 125], ['addx', 8, 127], ['noop', '', 128], ['addx', -1, 130], ['addx', 2, 132], ['addx', 1, 134], ['noop', '', 135], ['addx', 17, 137], ['addx', -9, 139], ['addx', 1, 141], ['addx', 1, 143], ['addx', -3, 145], ['addx', 11, 147], ['noop', '', 148], ['noop', '', 149], ['addx', 1, 151], ['noop', '', 152], ['addx', 1, 154], ['noop', '', 155], ['noop', '', 156], ['addx', -13, 158], ['addx', -19, 160], ['addx', 1, 162], ['addx', 3, 164], ['addx', 26, 166], ['addx', -30, 168], ['addx', 12, 170], ['addx', -1, 172], ['addx', 3, 174], ['addx', 1, 176], ['noop', '', 177], ['noop', '', 178], ['noop', '', 179], ['addx', -9, 181], ['addx', 18, 183], ['addx', 1, 185], ['addx', 2, 187], ['noop', '', 188], ['noop', '', 189], ['addx', 9, 191], ['noop', '', 192], ['noop', '', 193], ['noop', '', 194], ['addx', -1, 196], ['addx', 2, 198], ['addx', -37, 200], ['addx', 1, 202], ['addx', 3, 204], ['noop', '', 205], ['addx', 15, 207], ['addx', -21, 209], ['addx', 22, 211], ['addx', -6, 213], ['addx', 1, 215], ['noop', '', 216], ['addx', 2, 218], ['addx', 1, 220], ['noop', '', 221], ['addx', -10, 223], ['noop', '', 224], ['noop', '', 225], ['addx', 20, 227], ['addx', 1, 229], ['addx', 2, 231], ['addx', 2, 233], ['addx', -6, 235], ['addx', -11, 237], ['noop', '', 238], ['noop', '', 239], ['noop', '', 240]]

# %%
def nthStep(step):
  pos = len([step - item[2] for item in input if step - item[2] >= 0])
  
  if input[pos-1][2] == step and input[pos-1][0] == 'addx':
    pos -= 1
  elif input[pos][0] != 'addx':
    pos += 1

  # print(input[:pos])

  ignore = list(filter(lambda i: i[0] != 'noop', input[:pos]))
  ignoreTotal = sum([i[1] for i in ignore])

  print(ignoreTotal + 1)
  return (ignoreTotal + 1)

# nthStep(220)
print(sum([nthStep(i) * i for i in [20, 60, 100, 140, 180, 220]]))
# Out:
# 21
# 21
# 21
# 16
# 21
# 21
# 14420

# %%
from copy import deepcopy
import numpy as np
np.set_printoptions(threshold=np.inf, linewidth=500)

x = 1
program = []
c_input = deepcopy(input)
cmd = c_input.pop(0)
i = 1
delay = 0
while i < 240:
  program.append([x, i])
  if delay > 0:
    delay -= 1
    i += 1
    continue
  else:
    if cmd[0] == 'addx':
      delay = 3
      x += cmd[1]
      cmd = c_input.pop(0)
    else:
      delay = 2 
      cmd = c_input.pop(0)
    i += 1

print(program)
# overlap = [c for c in program if c[0] in range(c[1] - 3, c[1] + 3)]
