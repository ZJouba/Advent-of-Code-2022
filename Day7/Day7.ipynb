# %% [markdown]
# <a href="https://colab.research.google.com/github/ZJouba/Advent-of-Code-2022/blob/main/Day7/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

file = requests.get('https://raw.githubusercontent.com/ZJouba/Advent-of-Code-2022/main/Day7/Day7.txt')
input = list(filter(None, file.text.split('\n')))

# file = '''
# $ cd /
# $ ls
# dir a
# 14848514 b.txt
# 8504156 c.dat
# dir d
# $ cd a
# $ ls
# dir e
# 29116 f
# 2557 g
# 62596 h.lst
# $ cd e
# $ ls
# 584 i
# $ cd ..
# $ cd ..
# $ cd d
# $ ls
# 4060174 j
# 8033020 d.log
# 5626152 d.ext
# 7214296 k'''

# input = list(filter(None, file.split('\n')))

# print(input)

# %%
files = []
currentPath = ''

for item in input:
  item = item.split(' ')
  if item[1] == 'cd':
    currentPath = ''.join([e+';' for e in currentPath.split(';')[0:-2] if e]) if item[2] == '..' else currentPath + item[2] + ';'
  if item[0].isnumeric():
    files.append([item[0], item[1], currentPath])

from itertools import groupby, zip_longest
totals = [[k, sum(int(i[0]) for i in g)] for k, g in groupby(files, key=lambda i: i[2])]

directories = {}
# applicable = list(filter(lambda x: x[1] <= 100000, totals))
test = [list(filter(None, [*i[0].split(';'), i[1]])) for i in totals]
cols = [sum(list(filter(lambda i: isinstance(i, int),x))) for x in zip_longest(*test, fillvalue=0)]

print(*test, sep='\n')
print(cols)

for item in totals:
  for i in list(filter(None, item[0].split(';'))):
    if i in directories:
      directories[i] += item[1]
    else:
      directories[i] = item[1]

# print(directories)

# print(sum([v for k,v in directories.items() if v <= 100000]))
# Out:
# ['/', 55644]
# ['/', 'cmwrq', 67100]
# ['/', 'cmwrq', 'dtbzzl', 42503]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 160150]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'lwqgsbg', 829824]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'lwqgsbg', 'dtbzzl', 252091]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'lwqgsbg', 'pjts', 374873]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'lwqgsbg', 'sbvljdh', 'rdrqc', 242263]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'lwqgsbg', 'sbvljdh', 'rtfpcswj', 228044]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'nztw', 30777]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'rdtjztmt', 581691]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'rdtjztmt', 'rzbb', 155253]
# ['/', 'cmwrq', 'dtbzzl', 'wwpnn', 'ssdlqcrw', 22423]
# ['/', 'cmwrq', 'pjnghbm', 394690]
# ['/', 'cmwrq', 'pjnghbm', 'dtbzzl', 720013]
# ['/', 'cmwrq', 'pjnghbm', 'dtbzzl', 'hlw', 'lfqqrp', 'mbmfpz', 'fsrbwl', 617802]
# ['/', 'cmwrq', 'pjnghbm', 'dtbzzl', 'hlw', 'lfqqrp', 'mbmfpz', 'fsrbwl', 'ltsj', 51204]
# ...
